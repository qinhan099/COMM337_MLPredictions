# %%
# Group Information
# Group 30:
# Francis Ding - 74307844 RQ 2 Case Design and ML Prediction.
# Jiarun Pan 47294608 - RQ 1 Data comparison and visualization.
# Han Qin 25140877 - RQ 2 Data Labeling and Transforming.

# %%
### PART II - Research Question 2
### Given the following case: in May 2023, a woman wants to take a 5th-class class-change Road Test in Vancouver island.
### Will she, most probably, pass or fail.

# %%
## 1. Importing Libraries for usage of the project.
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %config InlineBackend.figure_format='retina' # display figures in retina quality
from sklearn.cluster import KMeans
from sklearn.linear_model import LogisticRegression
from warnings import simplefilter
simplefilter(action='ignore', category=FutureWarning)

from sklearn.preprocessing import LabelEncoder

# %%
## 2. Importing our dataset and drop error NA values.

df = pd.read_csv('BC_driver_license_test.csv')
# Out:
# /var/folders/nb/6qcxnwwn63qflk99ycftkdcr0000gn/T/ipykernel_13145/1908921218.py:3: DtypeWarning: Columns (2) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('BC_driver_license_test.csv')

# %%
df = df.dropna()
df.shape
# Out:
# (1417534, 12)

# %%
## 3.Datawashing, clean the unnecessary details of strs.

# %%
driver_exam_breakdown_indicator = []
for i in range(len(df['driver_exam_breakdown'])):
    driver_exam_breakdown_indicator.append(df['driver_exam_breakdown'][i][6])
    
df['driver_exam_breakdown'] = driver_exam_breakdown_indicator

# %%
df
# Out:
#          test_id driver_exam_breakdown  year exam_month   exam_reason  \
# 0              0                     6  2017        May       Re-test
# 1              1                     6  2017        May       Re-test
# 2              2                     6  2017        May       Re-test
# 3              3                     6  2017        May       Re-test
# 4              4                     6  2017        May       Re-test
# ...          ...                   ...   ...        ...           ...
# 1417529  1417529                     5  2018       June  Class Change
# 1417530  1417530                     5  2018       June  Class Change
# 1417531  1417531                     5  2018       June  Class Change
# 1417532  1417532                     5  2018       June  Class Change
# 1417533  1417533                     5  2018       June  Class Change
#
#         exam_result          exam_type  gender office_municiplaity  \
# 0            Failed  Motorcycle Skills    Male              SURREY
# 1            Failed  Motorcycle Skills    Male              SURREY
# 2            Passed  Motorcycle Skills  Female          PORT HARDY
# 3            Passed  Motorcycle Skills    Male              SURREY
# 4            Passed  Motorcycle Skills    Male              SURREY
# ...             ...                ...     ...                 ...
# 1417529      Passed               Road  Female         NANAIMO DLO
# 1417530      Passed               Road  Female         NANAIMO DLO
# 1417531      Passed               Road  Female         NANAIMO DLO
# 1417532      Passed               Road  Female         NANAIMO DLO
# 1417533      Passed               Road  Female         NANAIMO DLO
#
#                    region  exam_class   exam_date
# 0          Lower Mainland           6  2017-05-09
# 1          Lower Mainland           6  2017-05-09
# 2        Vancouver Island           6  2017-05-09
# 3          Lower Mainland           6  2017-05-09
# 4          Lower Mainland           6  2017-05-09
# ...                   ...         ...         ...
# 1417529  Vancouver Island           5  2018-06-20
# 1417530  Vancouver Island           5  2018-06-20
# 1417531  Vancouver Island           5  2018-06-25
# 1417532  Vancouver Island           5  2018-06-25
# 1417533  Vancouver Island           5  2018-06-25
#
# [1417534 rows x 12 columns]

# %%
# 4.Costumize our label encoder, since using label encoder.applyall will mess up infos with weird values.
##  Use Supervised learning method le. -> label encoder to automate binary transform our data.
##  Since we already have our label encoder ----> le. we can use all methods from le.

## encode exam_month by specifying the encoder.class ---> else the May will be displayed as 8.
# Define a custom mapping of month names to numerical labels
month_map = {'January': 1, 'February': 2, 'March': 3, 'April': 4, 'May': 5,
             'June': 6, 'July': 7, 'August': 8, 'September': 9, 'October': 10, 'Novemember': 11, 'December':12}

# Create a LabelEncoder object and set its mapping to the custom mapping
le = LabelEncoder()
le.fit(df['exam_month'].str.strip().map(month_map))

# Transform the exam_month column into numerical labels
df['exam_month_encoded'] = le.transform(df['exam_month'].str.strip().map(month_map)) + 1
df['exam_month'] = df['exam_month_encoded']

# %%
df
# Out:
#          test_id driver_exam_breakdown  year  exam_month   exam_reason  \
# 0              0                     6  2017           5       Re-test
# 1              1                     6  2017           5       Re-test
# 2              2                     6  2017           5       Re-test
# 3              3                     6  2017           5       Re-test
# 4              4                     6  2017           5       Re-test
# ...          ...                   ...   ...         ...           ...
# 1417529  1417529                     5  2018           6  Class Change
# 1417530  1417530                     5  2018           6  Class Change
# 1417531  1417531                     5  2018           6  Class Change
# 1417532  1417532                     5  2018           6  Class Change
# 1417533  1417533                     5  2018           6  Class Change
#
#         exam_result          exam_type  gender office_municiplaity  \
# 0            Failed  Motorcycle Skills    Male              SURREY
# 1            Failed  Motorcycle Skills    Male              SURREY
# 2            Passed  Motorcycle Skills  Female          PORT HARDY
# 3            Passed  Motorcycle Skills    Male              SURREY
# 4            Passed  Motorcycle Skills    Male              SURREY
# ...             ...                ...     ...                 ...
# 1417529      Passed               Road  Female         NANAIMO DLO
# 1417530      Passed               Road  Female         NANAIMO DLO
# 1417531      Passed               Road  Female         NANAIMO DLO
# 1417532      Passed               Road  Female         NANAIMO DLO
# 1417533      Passed               Road  Female         NANAIMO DLO
#
#                    region  exam_class   exam_date  exam_month_encoded
# 0          Lower Mainland           6  2017-05-09                   5
# 1          Lower Mainland           6  2017-05-09                   5
# 2        Vancouver Island           6  2017-05-09                   5
# 3          Lower Mainland           6  2017-05-09                   5
# 4          Lower Mainland           6  2017-05-09                   5
# ...                   ...         ...         ...                 ...
# 1417529  Vancouver Island           5  2018-06-20                   6
# 1417530  Vancouver Island           5  2018-06-20                   6
# 1417531  Vancouver Island           5  2018-06-25                   6
# 1417532  Vancouver Island           5  2018-06-25                   6
# 1417533  Vancouver Island           5  2018-06-25                   6
#
# [1417534 rows x 13 columns]

# %%
#-------------------------------------------------------------------------------------
# Now We've established cleaning for classes and month, let's apply encoding to all other components that
# does not involve any numerical relationship with the string.

# first train le to fit exam_reason.
le.fit(df['exam_reason'])
df['exam_reason_encoded'] = le.transform(df['exam_reason'])

# %%
# Verify each corresponding components.
print(df['exam_reason'].unique())
# Out:
# ['Re-test' 'Upgrade' 'Re-exam' 'Class Change' 'Original'
#  'Restriction Change' 'Information not available' 'Downgrade'
#  'New Licence']

# %%
print(df['exam_reason_encoded'].unique())
# Out:
# [6 8 5 0 4 7 2 1 3]

# %% [markdown]
# ##### Where we could've categorize them in this tab.
# #####
#
# ## Exam_Reason:
#     0 - Class Change              1 - Downgrade
#     2 - Information not available 3 - New Licence
#     4 - Original                  5 - Re-exam
#     6 - Re-test                   7 - Restriction Change
#     8 - Upgrade

# %%
## train and fit exam result
## Which is a simple binary, Pass = 1, Fail = 0.
le.fit(df['exam_result'])
df['exam_result_encoded'] = le.transform(df['exam_result'])

# %%
## train and fit exam_type
## Which is a binary as well, Motorcycle = 0, Road = 1.
print(df['exam_type'].unique())
le.fit(df['exam_type'])
df['exam_type_encoded'] = le.transform(df['exam_type'])
# Out:
# ['Motorcycle Skills' 'Road']

# %%
## train and fit gender.
## Where there are 3 values, Male = 2 , Female = 0, INA =1.
print(df['gender'].unique())
le.fit(df['gender'])
df['gender_encoded'] = le.transform(df['gender'])
# Out:
# ['Male' 'Female' 'Information not available']

# %%
## train and fit region
## Since region has multiple locations, we have to display them using tables.
le.fit(df['region'])
df['region_encoded'] = le.transform(df['region'])

# %%
## Aligning
## Lower Mainland: 0   Vancouver Island: 4
## North Central: 1    Southern Interior: 2
## Unknown: 3
df['region'].unique()
# Out:
# array(['Lower Mainland', 'Vancouver Island', 'North Central',
#        'Southern Interior', 'Unknown'], dtype=object)

# %%
df['region_encoded'].unique()
# Out:
# array([0, 4, 1, 2, 3])

# %%
df
# Out:
#          test_id driver_exam_breakdown  year  exam_month   exam_reason  \
# 0              0                     6  2017           5       Re-test
# 1              1                     6  2017           5       Re-test
# 2              2                     6  2017           5       Re-test
# 3              3                     6  2017           5       Re-test
# 4              4                     6  2017           5       Re-test
# ...          ...                   ...   ...         ...           ...
# 1417529  1417529                     5  2018           6  Class Change
# 1417530  1417530                     5  2018           6  Class Change
# 1417531  1417531                     5  2018           6  Class Change
# 1417532  1417532                     5  2018           6  Class Change
# 1417533  1417533                     5  2018           6  Class Change
#
#         exam_result          exam_type  gender office_municiplaity  \
# 0            Failed  Motorcycle Skills    Male              SURREY
# 1            Failed  Motorcycle Skills    Male              SURREY
# 2            Passed  Motorcycle Skills  Female          PORT HARDY
# 3            Passed  Motorcycle Skills    Male              SURREY
# 4            Passed  Motorcycle Skills    Male              SURREY
# ...             ...                ...     ...                 ...
# 1417529      Passed               Road  Female         NANAIMO DLO
# 1417530      Passed               Road  Female         NANAIMO DLO
# 1417531      Passed               Road  Female         NANAIMO DLO
# 1417532      Passed               Road  Female         NANAIMO DLO
# 1417533      Passed               Road  Female         NANAIMO DLO
#
#                    region  exam_class   exam_date  exam_month_encoded  \
# 0          Lower Mainland           6  2017-05-09                   5
# 1          Lower Mainland           6  2017-05-09                   5
# 2        Vancouver Island           6  2017-05-09                   5
# 3          Lower Mainland           6  2017-05-09                   5
# 4          Lower Mainland           6  2017-05-09                   5
# ...                   ...         ...         ...                 ...
# 1417529  Vancouver Island           5  2018-06-20                   6
# 1417530  Vancouver Island           5  2018-06-20                   6
# 1417531  Vancouver Island           5  2018-06-25                   6
# 1417532  Vancouver Island           5  2018-06-25                   6
# 1417533  Vancouver Island           5  2018-06-25                   6
#
#          exam_reason_encoded  exam_result_encoded  exam_type_encoded  \
# 0                          6                    0                  0
# 1                          6                    0                  0
# 2                          6                    1                  0
# 3                          6                    1                  0
# 4                          6                    1                  0
# ...                      ...                  ...                ...
# 1417529                    0                    1                  1
# 1417530                    0                    1                  1
# 1417531                    0                    1                  1
# 1417532                    0                    1                  1
# 1417533                    0                    1                  1
#
#          gender_encoded  region_encoded
# 0                     2               0
# 1                     2               0
# 2                     0               4
# 3                     2               0
# 4                     2               0
# ...                 ...             ...
# 1417529               0               4
# 1417530               0               4
# 1417531               0               4
# 1417532               0               4
# 1417533               0               4
#
# [1417534 rows x 18 columns]

# %%
##5. After we've encoded all columns that we need, now we've can create a new column only contains the encoded codes,
###  and count for the option that has the greatest correlation with pass for exam.

# %%
edf = df.loc[:, ['exam_class', 'exam_month_encoded', 
                 'exam_reason_encoded', 'exam_result_encoded', 'exam_type_encoded',
                 'gender_encoded', 'region_encoded']]

## Here we do not take the data of "year" and "municipality" into account because:
##(a) "year" is historical data and will not reappear in the future, data for this variable is not helpful for predicting results;
##(b) "office_municiplaity" has more than 100 values, which is too complex and will reduce the accuracy of prediction. And a municipality has and only corresponds to one region, so using region to predict will increase the accuracy of prediction.

# %%
edf
# Out:
#          exam_class  exam_month_encoded  exam_reason_encoded  \
# 0                 6                   5                    6
# 1                 6                   5                    6
# 2                 6                   5                    6
# 3                 6                   5                    6
# 4                 6                   5                    6
# ...             ...                 ...                  ...
# 1417529           5                   6                    0
# 1417530           5                   6                    0
# 1417531           5                   6                    0
# 1417532           5                   6                    0
# 1417533           5                   6                    0
#
#          exam_result_encoded  exam_type_encoded  gender_encoded  \
# 0                          0                  0               2
# 1                          0                  0               2
# 2                          1                  0               0
# 3                          1                  0               2
# 4                          1                  0               2
# ...                      ...                ...             ...
# 1417529                    1                  1               0
# 1417530                    1                  1               0
# 1417531                    1                  1               0
# 1417532                    1                  1               0
# 1417533                    1                  1               0
#
#          region_encoded
# 0                     0
# 1                     0
# 2                     4
# 3                     0
# 4                     0
# ...                 ...
# 1417529               4
# 1417530               4
# 1417531               4
# 1417532               4
# 1417533               4
#
# [1417534 rows x 7 columns]

# %%
##### Step 6.
##### Train the Model with our selected question, given a dataset to predict whether the dataset is going to pass or 
##### fail? In order to predict wether a set of data will pass or fail, we have to set our target predictive dataset 
##### as Y, and our inputdatasets as all other numerical columns.
##### We can use Multiple classifiers and predicter modules to solve this problem from sklearn.
##### We are going to use the RandomForest classifier to train our predictive model, and use a random dataset we made
##### up to test the effectiveness of the model.

# %%
X = edf.loc[:, ['exam_class', 'exam_month_encoded', 'exam_reason_encoded','exam_type_encoded',
                'gender_encoded', 'region_encoded']].values

y = edf.loc[:, ['exam_result_encoded']].values

# %%
X
# Out:
# array([[6, 5, 6, 0, 2, 0],
#        [6, 5, 6, 0, 2, 0],
#        [6, 5, 6, 0, 0, 4],
#        ...,
#        [5, 6, 0, 1, 0, 4],
#        [5, 6, 0, 1, 0, 4],
#        [5, 6, 0, 1, 0, 4]])

# %%
y
# Out:
# array([[0],
#        [0],
#        [1],
#        ...,
#        [1],
#        [1],
#        [1]])

# %%
type(X)
# Out:
# numpy.ndarray

# %%
type(y)
# Out:
# numpy.ndarray

# %%
#### The first thing to do after we've created the dataset is to split the dataset to training sets and test sets.
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 0)

# %%
print(X_train.shape)
print(X_test.shape)
# Out:
# (1134027, 6)
# (283507, 6)

# %%
print(y_train.shape)
print(y_test.shape)
# Out:
# (1134027, 1)
# (283507, 1)

# %%
y_train = y_train.ravel()

# %%
y_test = y_test.ravel()

# %%
y_test.shape
# Out:
# (283507,)

# %%
#### Find the best N estimator for RandomForest by using the 5Fold cross-validation.
from sklearn.ensemble import RandomForestClassifier

# %%
from sklearn.model_selection import KFold


lowest_cross_val_error = np.inf
best_n_estimators = None

indices = range(len(X_train))
kf = KFold(n_splits=5, shuffle=True, random_state=0) #将train data再次分为五个fold

for k in range(5,101,5):
    
    errors = []
    
    for train_indices, val_indices in kf.split(indices):
        
        classifier = RandomForestClassifier(n_estimators=k, random_state=0)
        
        classifier.fit(X_train[train_indices],
                       y_train[train_indices])
        
        predicted_val_labels = classifier.predict(X_train[val_indices])
        
        error = np.mean(predicted_val_labels != y_train[val_indices])
        
        errors.append(error)
        
    cross_val_error = np.mean(errors)
    print('n_estimators:', k, 'cross validation error:', cross_val_error)

    if cross_val_error < lowest_cross_val_error:
        lowest_cross_val_error = cross_val_error
        best_n_estimators = k

print('\nBest n_estimators:', best_n_estimators, '\ncross validation error:', lowest_cross_val_error)
# Out:
# n_estimators: 5 cross validation error: 0.3601578332498867
# n_estimators: 10 cross validation error: 0.36015425696778963
# n_estimators: 15 cross validation error: 0.3601041890184298
# n_estimators: 20 cross validation error: 0.3600803471377822
# n_estimators: 25 cross validation error: 0.36011372577068884
# n_estimators: 30 cross validation error: 0.36019359607085805
# n_estimators: 35 cross validation error: 0.36008511551391165
# n_estimators: 40 cross validation error: 0.360101804830365
# n_estimators: 45 cross validation error: 0.36010061273633265
# n_estimators: 50 cross validation error: 0.36006842619745844
# n_estimators: 55 cross validation error: 0.3600064373077748
# n_estimators: 60 cross validation error: 0.36003504756455185
# n_estimators: 65 cross validation error: 0.36001478196600145
# n_estimators: 70 cross validation error: 0.3600123977779367
# n_estimators: 75 cross validation error: 0.3600183582480986
# n_estimators: 80 cross validation error: 0.3600314712824547
# n_estimators: 85 cross validation error: 0.3600410080347137
# n_estimators: 90 cross validation error: 0.36003504756455185
# n_estimators: 95 cross validation error: 0.36008988389004126
# n_estimators: 100 cross validation error: 0.3600457764108433
#
# Best n_estimators: 55
# cross validation error: 0.3600064373077748

# %%
## Best n_estimator = 55.
## We will create our randomForest method to train and predict results for our research question.

# %%
##look at the test data to evaluate performance of the model with the best n_estimators
best_n_estimators = 55
final_rf_classifier = RandomForestClassifier(n_estimators = best_n_estimators, random_state=0)
final_rf_classifier.fit(X_train, y_train)

predicted_y_test = final_rf_classifier.predict(X_test)

error_rate = np.mean(predicted_y_test != y_test)
print(error_rate)
# Out:
# 0.39584560522315143

# %%
#Finally input the data and get the prediction
#We set the scenario: in May 2023, a woman wants to take a 5th-class class-change Road Test in Vancouver island.
#Will she, most probably, pass the exam?

#Exam_class = 5, exam_month = 5,Exam_Reason = 0,Exam_type = 1, gender = 0, region = 4
predicted_y_test_assumption = final_rf_classifier.predict([[5,5,0,1,0,4]]) 
predicted_y_test_assumption
# Out:
# array([1])

# %%
#Thus, our conclusion is that by training the randomForest model using the selected datasets, the result tells us
#that the case will mostly pass.
